# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimberly1229/Yoonyoung-Kim-Skyline-Math-200/blob/main/Python_Notebook_Setup2_by_Yoonyoung_Kim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question #2 : Is there an association between Communication with father and Independency?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# *Codebook* 1

# %% [markdown]
# ![H4WP37.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['Communication_Father'] = df['H4WP37']
df['Communication_Father'] = df['Communication_Father'].loc[ df['Communication_Father'] !=' ']
df['Communication_Father'] = df['Communication_Father'].loc[ df['Communication_Father'] !='6']
df['Communication_Father'] = df['Communication_Father'].loc[ df['Communication_Father'] !='7']
df['Communication_Father'] = df['Communication_Father'].loc[ df['Communication_Father'] !='8']
df['Communication_Father'].replace(['1','2','3','4','5'] , ['strongly agree','agree','neither agree nor disagree','disagree','strongly disagree' ], inplace = True)
df['Communication_Father'].value_counts()
# Out:
# strongly agree                1986
# agree                         1398
# neither agree nor disagree     355
# disagree                       256
# strongly disagree              234
# Name: Communication_Father, dtype: int64

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Communication_Father'])
# Out:
#                Variable                     Outcome  Count  Percent
# 0  Communication_Father              strongly agree   1986    46.96
# 1                                             agree   1398    33.06
# 2                        neither agree nor disagree    355     8.39
# 3                                          disagree    256     6.05
# 4                                 strongly disagree    234     5.53

# %%
#Graphs and tables or statistics

# %%
plt.title("You are satisfied with the way your father and you communicate with each other.")
df['Communication_Father'].value_counts().plot(kind ='pie',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'You are satisfied with the way your father and you communicate with each other.'}, ylabel='Communication_Father'>

# %%
plt.ylabel("Percent")
plt.title("You are satisfied with the way your father and you communicate with each other.")
df['Communication_Father'].value_counts(normalize = True).plot(kind ='barh',color = 'Navy', width = 0.4, alpha = 0.8)
# Out:
# <Axes: title={'center': 'You are satisfied with the way your father and you communicate with each other.'}, ylabel='Percent'>

# %% [markdown]
# *Codebook* 2

# %% [markdown]
# ![H4PE38.png](data:image/png;base64,...)

# %%
#Manage data for variable 2
df['Independency'] = df['H4PE38']
df['Independency'] = df['Independency'].loc[ df['Independency'] !=' ']
df['Independency'] = df['Independency'].loc[ df['Independency'] !='6']
df['Independency'] = df['Independency'].loc[ df['Independency'] !='8']
df['Independency'] = df['Independency'].loc[ df['Independency'] !='.']
df['Independency'].replace(['1','2','3','4','5'] , ['strongly agree','agree','neither agree nor disagree','disagree','strongly disagree' ], inplace = True)
df['Independency'].value_counts()
# Out:
# disagree                      2880
# strongly disagree             1627
# neither agree nor disagree     369
# agree                          185
# strongly agree                  42
# Name: Independency, dtype: int64

# %%
rp.summary_cat(df['Independency'])
# Out:
#        Variable                     Outcome  Count  Percent
# 0  Independency                    disagree   2880    56.44
# 1                         strongly disagree   1627    31.88
# 2                neither agree nor disagree    369     7.23
# 3                                     agree    185     3.63
# 4                            strongly agree     42     0.82

# %%
#Graphs and tables or statistics

# %%
plt.title("Other people determine most of what I can and cannot do.")
df['Independency'].value_counts().plot(kind ='pie',autopct='%1.1f%%',startangle = 320)
# Out:
# <Axes: title={'center': 'Other people determine most of what I can and cannot do.'}, ylabel='Independency'>

# %%
plt.ylabel("Percent")
plt.title("Other people determine most of what I can and cannot do.")
df['Independency'].value_counts(normalize = True).plot(kind ='barh',color = 'Blue', width = 0.4, alpha = 0.4)
# Out:
# <Axes: title={'center': 'Other people determine most of what I can and cannot do.'}, ylabel='Percent'>
